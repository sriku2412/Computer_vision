# %%
# bbuilding a simple linear regression model using nural network and functions of tensorflow

import pandas as pd 

import seaborn as sns

data = sns.load_dataset('iris')

data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['species'] = le.fit_transform(data['species'])
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
# building a linear regression model
import tensorflow as tf
def linear_regression_model():
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(1, input_shape=(4,)))
    model.compile(optimizer='sgd', loss='mse')
    return model

model = linear_regression_model()
model.fit(data.drop('species', axis=1), data['species'], epochs=10)
# Out:
# WARNING:tensorflow:From c:\Users\srika\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\srika\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\srika\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\srika\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 5/5 [==============================] - 1s 3ms/step - loss: 0.6599
# Epoch 2/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3252
# Epoch 3/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2432
# Epoch 4/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2112
# Epoch 5/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1609
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1243
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1160
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1138
# Epoch 9/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1158
# Epoch 10/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1021
